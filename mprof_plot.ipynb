# %%
# %matplotlib widget
from mprof_plotter import plot_file
from mprof_plotter import read_mprofile_file

# %%
# read_mprofile_file('mprofile_20230823132627.dat')

# %%
file = 'mprofile_20230823162801.dat'
file = 'mprofile_20230823173957.dat'
plot_file(file);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
