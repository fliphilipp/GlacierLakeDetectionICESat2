# %%
# %matplotlib widget
from mprof_plotter import plot_file
from mprof_plotter import read_mprofile_file

# %%
# read_mprofile_file('mprofile_20230829205805.dat')

# %%
file = 'mprofile_20230823162801.dat'
file = 'mprofile_20230823173957.dat'
file = 'mprofile_20230824105554.dat'
file = 'mprofile_20230829205805.dat'
file = 'mprofile_20230829212215.dat'
file = 'mprofile_20230829231841.dat'
file = 'mprofile_20230831141507.dat' # small granule in CW greenland that has some lakes and works
file = 'mprofile_20230831153531.dat' # < 4GB granule
plot_file(file);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
file = 'mprofile_20230829225710.dat'
plot_file(file);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
file = 'mprofile_20230823162801.dat'
file = 'mprofile_20230823173957.dat'
plot_file(file);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
