# %%
import fiona
import numpy as np
import pandas as pd
import datetime
from icelakes.nsidc import make_granule_list
from icelakes.nsidc import shp2geojson
import datetime

# %%
txt = '''PASTE BELOW: 

var geometry = /* color: #ff0000 */ee.Geometry.Polygon(
        [[[-25.530185156418064, 77.26482930571373],
          [-22.475985937668064, 77.20170706198175],
          [-21.750888281418064, 78.03530746531358],
          [-25.024814062668064, 78.07169384722728]]]);

'''
txt = 'np.array(' + txt[txt.find('[[[')+1:].replace(']]]);', ']])')
print('poly_coords = ' + ''.join(txt.split()).replace('PASTEBELOW:',''))
# Out:
# poly_coords = np.array([[-25.530185156418064,77.26482930571373],[-22.475985937668064,77.20170706198175],[-21.750888281418064,78.03530746531358],[-25.024814062668064,78.07169384722728]])

# %%
# shpname = 'shapefiles/shackleton_test.shp'
# poly_coords = np.array([[102.50273408053137,-66.0992842004533],[102.65928925631262,-65.90267697036126],[102.00010956881262,-65.82630850133168],[101.69249238131262,-65.77226443817733],[101.63756074068762,-65.67741405594391],[101.24205292818762,-65.60945036903114],[100.90147675631262,-65.55495108625189],[100.39610566256262,-65.60037508326863],[100.31920136568762,-65.77226443817733],[99.81383027193762,-65.88921668514566],[98.83604706881262,-66.00563795112738],[98.69322480318762,-66.1748409821529],[97.48472870943762,-66.21031923781982],[96.21031464693762,-66.31204221868005],[95.30943574068762,-66.39136545362466],[94.62828339693762,-66.57548006110306],[95.17759980318762,-66.89657934480684],[95.70494355318762,-66.89657934480684],[96.64976777193762,-66.75823913959461],[97.70445527193762,-66.80155430591608],[98.29771699068762,-66.7148475903708],[98.45152558443762,-67.1624011211281],[98.36363495943762,-67.95908866568828],[99.79185761568762,-67.96733284697459],[100.51695527193762,-67.50952737164907],[100.65977753756262,-67.37888853811923],[100.82457245943762,-67.18797167350702],[100.92344941256262,-66.93749905337754],[100.78612031100012,-66.7148475903708],[101.53319062350012,-66.63654996647453],[101.84080781100012,-66.3208683002427]])
# date = '2020-02-24'

# shpname = 'shapefiles/jakobshavn_small.shp'
# poly_coords = np.array([[-49.59098555896507,69.10415896488335],[-50.33805587146507,68.42374368072217],[-50.01945235584007,68.20452489563448],[-49.39323165271507,68.13916524792879],[-48.47038009021507,68.14325568125464],[-48.16276290271507,68.66085965388693],[-48.12980391834007,69.0963205694427]])

# shpname = 'shapefiles/weird_shape_test.shp'
# poly_coords = np.array([[-47.95795458584981,69.1239791817489],[-49.64984911709981,68.99834123900001],[-50.37494677334981,68.43206642934923],[-49.71576708584981,68.09846842851343],[-46.35395067959981,68.26180787325274],[-46.50775927334981,67.63488984600534],[-46.13422411709981,66.8616740585752],[-48.41938036709981,67.1364144946641],[-49.78168505459981,66.8789363821686],[-49.21039599209981,66.51386059479546],[-49.91352099209981,65.9828829552171],[-50.22113817959981,65.65889521361566],[-47.05707567959981,65.45888645823287],[-44.46430224209981,66.08997462377839],[-45.60688036709981,69.19433466803291]])

# shpname = 'shapefiles/79N_test.shp'
925984763,66.6447381360437],[-49.36642558797263,66.56184848827401],[-49.36642558797263,66.44797066124347],[-49.52987706420915,66.31360064609107],[-49.500090392789055,66.23547941403042],[-49.560515197476555,66.14900007845858],[-49.697844299039055,66.05999558060626],[-49.868132384976555,65.97515185791536],[-49.994475158414055,65.86083805358744],[-49.851652892789055,65.7978602741899],[-49.964915887563414,65.68367803101819],[-49.964915887563414,65.59304210644521],[-49.739696161000914,65.54760529593683],[-49.827586786000914,65.4268135605468],[-50.036327020375914,65.3215220026102],[-49.734202996938414,65.22731886515498],[-49.684764520375914,65.12815856901226],[-49.684764520375914,65.03558286289696],[-49.794627801625914,64.97058808481852],[-49.421538297663645,64.81905647728986],[-48.78477651840938,64.79103359143471],[-47.03245718247188,64.79805163813936],[-46.52918839062207,64.94954040977103],[-46.19959854687207,65.82791933860571],[-45.9607754221497,66.80022825934762],[-45.4993496408997,67.61726178615636],[-45.5432949533997,68.57612701248429],[-45.9607754221497,69.5111566900704],[-46.47388070070614,71.13988585395734],[-50.491781166583536,71.04395062694336],[-50.337972572833536,70.85389110990046],[-50.469808510333536,70.64015820051415]])
# date = '2019-06-17'

# %%
lonlatlist = list(zip(poly_coords[:,0],poly_coords[:,1]))
latlonlist = list(zip(poly_coords[:,1],poly_coords[:,0]))

# define schema
schema = {'geometry':'Polygon', 'properties':[('Name','str')]}
#open a fiona object
polyShp = fiona.open(shpname, mode='w', driver='ESRI Shapefile',
          schema = schema, crs = "EPSG:4326")

#save record and close shapefile
rowDict = {'geometry' : {'type':'Polygon','coordinates': [lonlatlist]},'properties': {'Name' : 'edge'}}
polyShp.write(rowDict)
polyShp.close()
geojson_fn = shp2geojson(shpname)
# Out:
# Wrote file: geojsons/amery_test.geojson

# %% [markdown]
# # query for a known granule
# enter date and run after running cell above

# %%
geojson_file = 'geojsons/amery_test.geojson'
date = date = '2022-02-16'

end_date = datetime.datetime.strftime(datetime.datetime.strptime(date, '%Y-%m-%d') + datetime.timedelta(days=1), '%Y-%m-%d')
start_date = date
outname = 'temp.csv'
make_granule_list(geojson_fn, start_date, end_date, outname, geojson_dir_local='')
pd.read_csv(outname,header=None)
# Out:
# Found 1 ATL03 version 005 granules over geojsons/amery_test.geojson between 2022-02-16 and 2022-02-17.
# Wrote file: temp.csv
#                                          0                            1
# 0  ATL03_20220216005735_08511412_005_01.h5  geojsons/amery_test.geojson

# %% [markdown]
# # plot shapefile to check

# %%
from ipyleaflet import Map, basemaps, Polygon, GeoData, LayersControl
import geopandas as gpd

polygon = Polygon(locations=latlonlist, color="green", fill_color="green", name='polygon')
jakobshavn = gpd.read_file(shpname)
geo_data = GeoData(geo_dataframe=jakobshavn,
                   style={'color': 'red', 'fillColor': 'red'},
                   name = 'Shapefile')
m=Map(basemap=basemaps.Esri.WorldImagery,center=[np.mean(poly_coords[:,1]),np.mean(poly_coords[:,0])],zoom=4)
m.add_layer(polygon)
m.add_layer(geo_data)
m.add_control(LayersControl())
m
# Out:
# Map(center=[67.80910463331948, -49.42840179478749], controls=(ZoomControl(options=['position', 'zoom_in_text',…
